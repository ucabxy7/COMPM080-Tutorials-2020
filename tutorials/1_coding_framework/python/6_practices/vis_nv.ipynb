# %% [markdown]
# ## Visualize vertex normals and change colors
#
#
# This practice is to implement a Viewer which supports normal vector visualization and interactively change mesh color using keyboard events.

# %%
import sys,os

RES_PATH = '../../../../resources'
LIB_PATH = '../../../../python_lib'

if not os.path.exists(RES_PATH):
    print( 'cannot find \COMPM080-Tutorials-2020\resources\, please update RES_PATH')
    exit(1)
else:
    print('found resources')

# append path 
sys.path.append(LIB_PATH) 
from geo_tools import rd_helper

import pyglet
pyglet.options['shadow_window'] = False

import pyrender
import numpy as np
import trimesh

import matplotlib
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# found resources
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mesh_fp = os.path.join(RES_PATH,  'bun_zipper_res3.ply' )
assert os.path.exists(mesh_fp), 'cannot found:'+mesh_fp 

#------------
# TODO - load mesh

bunny_mesh = trimesh.load(mesh_fp)

#------------

# %%
def create_vertex_normal_render_obj(trimesh_obj):
    
    #------------
    # TODO - create and return a render object to visualize vertex normal
    #
    # Hints:
    #    Trimesh.vertices
    #    Trimesh.vertex_normals
    # 
    #
    
    
    edges = None
    
    
    return edges
    #------------

# %%
# create render objects
mobj = pyrender.Mesh.from_trimesh(bunny_mesh)
vobj = create_vertex_normal_render_obj(bunny_mesh)


# add render objects into scene graph
scene = pyrender.Scene(ambient_light=0.4*np.array([1.0, 1.0, 1.0, 1.0]))

mesh_node=scene.add(mobj)
if vobj is not None:
    nv_node=scene.add(vobj)

# initial a context object
gctx={}

# record render objects
gctx['mesh_node']=mobj
gctx['nv_node']=vobj
gctx['show_mesh_node']=True
gctx['show_nv_node']  =True
gctx['scene']=scene
gctx['cur_scale']=1.0
gctx['cur_color']=np.array((0,255,0),dtype=np.uint8)

# %% [markdown]
# ## Run GUI
# ### Note that if a exception is raised, please restart kernel (via Kernal>Restart) to release deaded threads.
#
# <div><img src="../imgs/nvgui1.jpg" width="400" align="left" /></div>

# %%
def run_gui(scene):    
    
    # call GUI
    v=pyrender.Viewer(scene, use_raymond_lighting=True)
    del v
    
run_gui(scene)

# %% [markdown]
# ## Add keyboard evenets

# %%
def toogle_mesh_display(viewer,gctx):
    
    if gctx['mesh_node'] is None: 
        return 
    
    #------------
    # TODO - show/hide the input bunny mesh
    # hints: 
    #  show_mesh_node, mesh_node
    #
    
    #------------
    viewer._message_text = 'toogle_mesh_display'
    
def toogle_normal_display(viewer,gctx):
    
    if gctx['nv_node'] is None: 
        return 
    
    #------------
    # TODO - show/hide normal vectors
    # hints: 
    #  show_nv_node, nv_node
    #
    
    
    #------------
    viewer._message_text = 'toogle_normal_display'
    
def increase_color(viewer,gctx):
    
    # remove old node 
    if gctx['mesh_node'] is not None: 
        gctx['scene'].remove_node(gctx['mesh_node']) 
        gctx['mesh_node']=None 
        
        
    if gctx['nv_node'] is not None: 
        gctx['scene'].remove_node(gctx['nv_node']) 
        gctx['nv_node']=None 
    
    
    # decide a scalar factor
    gctx['cur_color'][1] = gctx['cur_color'][1]+255*0.1
    
    #------------
    # TODO 
    #   copy bunny mesh 
    #   update vertex colors
    #   rebuild render object
    #   add render object into scene
    #   update render nodes in gctx
    #       mesh_node
    #       nv_node
    
    
    #------------
    viewer._message_text = 'increase_color :'+str(gctx['cur_color'])
    
def resize_mesh(viewer,gctx):
    
    # remove old node 
    if gctx['mesh_node'] is not None: 
        gctx['scene'].remove_node(gctx['mesh_node']) 
        gctx['mesh_node']=None 
        
        
    if gctx['nv_node'] is not None: 
        gctx['scene'].remove_node(gctx['nv_node']) 
        gctx['nv_node']=None 
    
    
    # decide a scalar factor
    gctx['cur_scale'] = gctx['cur_scale']*1.005
    
    #------------
    # TODO 
    #   copy bunny mesh 
    #   apply transform to resize the mesh
    #   rebuild render object
    #   add render object into scene
    #   update render nodes in gctx
    #       > mesh_node
    #       > nv_node
    
    
    
    #------------
    viewer._message_text = 'rescale input mesh (x{:.2})'.format(gctx['cur_scale'])
    
    
def reset_scale(viewer,gctx):
    
    # remove old node 
    if gctx['mesh_node'] is not None: 
        gctx['scene'].remove_node(gctx['mesh_node']) 
        gctx['mesh_node']=None 
        
        
    if gctx['nv_node'] is not None: 
        gctx['scene'].remove_node(gctx['nv_node']) 
        gctx['nv_node']=None 
    
    
    # decide a scalar factor
    gctx['cur_scale'] = 1.0
    
    #------------
    # TODO 
    #   copy bunny mesh  
    #   rebuild render object
    #   add render object into scene
    #   update render node in gctx
    #       > mesh_node
    #       > nv_node
    
    
    
    #------------
    viewer._message_text = 'reset scale to (x{:.3})'.format(gctx['cur_scale'])

# %% [markdown]
# ## Call GUI
#
# ### press 4/5/6/7/z to test your GUI functions
# ### Note that if a exception is raised, please restart kernel (Kernal>Restart) in order to release deaded threads.

# %%
def run_gui(scene):    
    
    key_mapping={  
        '4':(toogle_mesh_display,[gctx]),
        '5':(toogle_normal_display,[gctx]),
        '6':(increase_color,[gctx]),
        '7':(resize_mesh,[gctx]),
        'z':(reset_scale,[gctx])
    }

    # call GUI
    v=pyrender.Viewer(scene, use_raymond_lighting=True, registered_keys=key_mapping)
    del v
    
gctx['cur_scale']=1.0
run_gui(scene)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\envs\geo_tutorials\lib\site-packages\networkx\classes\digraph.py in successors(self, n)
#     793         try:
# --> 794             return iter(self._succ[n])
#     795         except KeyError:
#
# KeyError: <pyrender.mesh.Mesh object at 0x000002A20F478710>
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     638             if event_handler:
#     639                 if self._allow_dispatch_event or not self._enable_event_queue:
# --> 640                     result = event_handler(msg, wParam, lParam)
#     641                 else:
#     642                     result = 0
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\win32\__init__.py in _event_key(self, msg, wParam, lParam)
#     709
#     710         if not repeat:
# --> 711             self.dispatch_event(ev, symbol, modifiers)
#     712
#     713         ctrl = modifiers & key.MOD_CTRL != 0
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\__init__.py in dispatch_event(self, *args)
#    1311     def dispatch_event(self, *args):
#    1312         if not self._enable_event_queue or self._allow_dispatch_event:
# -> 1313             if EventDispatcher.dispatch_event(self, *args) != False:
#    1314                 self._legacy_invalid = True
#    1315         else:
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\event.py in dispatch_event(self, event_type, *args)
#     368         if handler is not None:
#     369             try:
# --> 370                 if handler(*args):
#     371                     return EVENT_HANDLED
#     372             except TypeError as exception:
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyrender\viewer.py in on_key_press(self, symbol, modifiers)
#     676                 if len(tup) == 3:
#     677                     kwargs = tup[2]
# --> 678             callback(self, *args, **kwargs)
#     679             return
#     680
#
# <ipython-input-15-afbbdce676dd> in increase_color(viewer, gctx)
#      32     # remove old node
#      33     if gctx['mesh_node'] is not None:
# ---> 34         gctx['scene'].remove_node(gctx['mesh_node'])
#      35         gctx['mesh_node']=None
#      36
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyrender\scene.py in remove_node(self, node)
#     428         """
#     429         # Disconnect self from parent who is staying in the graph
# --> 430         parent = list(self._digraph.neighbors(node))[0]
#     431         self._remove_node(node)
#     432         if isinstance(parent, Node):
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\networkx\classes\digraph.py in successors(self, n)
#     794             return iter(self._succ[n])
#     795         except KeyError:
# --> 796             raise NetworkXError("The node %s is not in the digraph." % (n,))
#     797
#     798     # digraph definitions
#
# NetworkXError: The node <pyrender.mesh.Mesh object at 0x000002A20F478710> is not in the digraph.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\envs\geo_tutorials\lib\site-packages\networkx\classes\digraph.py in successors(self, n)
#     793         try:
# --> 794             return iter(self._succ[n])
#     795         except KeyError:
#
# KeyError: <pyrender.mesh.Mesh object at 0x000002A20F478710>
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\win32\__init__.py in f(hwnd, msg, wParam, lParam)
#     638             if event_handler:
#     639                 if self._allow_dispatch_event or not self._enable_event_queue:
# --> 640                     result = event_handler(msg, wParam, lParam)
#     641                 else:
#     642                     result = 0
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\win32\__init__.py in _event_key(self, msg, wParam, lParam)
#     709
#     710         if not repeat:
# --> 711             self.dispatch_event(ev, symbol, modifiers)
#     712
#     713         ctrl = modifiers & key.MOD_CTRL != 0
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\window\__init__.py in dispatch_event(self, *args)
#    1311     def dispatch_event(self, *args):
#    1312         if not self._enable_event_queue or self._allow_dispatch_event:
# -> 1313             if EventDispatcher.dispatch_event(self, *args) != False:
#    1314                 self._legacy_invalid = True
#    1315         else:
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyglet\event.py in dispatch_event(self, event_type, *args)
#     368         if handler is not None:
#     369             try:
# --> 370                 if handler(*args):
#     371                     return EVENT_HANDLED
#     372             except TypeError as exception:
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyrender\viewer.py in on_key_press(self, symbol, modifiers)
#     676                 if len(tup) == 3:
#     677                     kwargs = tup[2]
# --> 678             callback(self, *args, **kwargs)
#     679             return
#     680
#
# <ipython-input-15-afbbdce676dd> in resize_mesh(viewer, gctx)
#      62     # remove old node
#      63     if gctx['mesh_node'] is not None:
# ---> 64         gctx['scene'].remove_node(gctx['mesh_node'])
#      65         gctx['mesh_node']=None
#      66
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\pyrender\scene.py in remove_node(self, node)
#     428         """
#     429         # Disconnect self from parent who is staying in the graph
# --> 430         parent = list(self._digraph.neighbors(node))[0]
#     431         self._remove_node(node)
#     432         if isinstance(parent, Node):
#
# D:\anaconda\envs\geo_tutorials\lib\site-packages\networkx\classes\digraph.py in successors(self, n)
#     794             return iter(self._succ[n])
#     795         except KeyError:
# --> 796             raise NetworkXError("The node %s is not in the digraph." % (n,))
#     797
#     798     # digraph definitions
#
# NetworkXError: The node <pyrender.mesh.Mesh object at 0x000002A20F478710> is not in the digraph.
